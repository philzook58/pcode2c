# %%
import pcode2c
import pcode2c.util
import pcode2c.printer

# %%
pcode2c.util.asm(r"mov %eax, %ebx")
# Out:
# /tmp/tmp92z1hfl0.s: Assembler messages:
# /tmp/tmp92z1hfl0.s: Warning: end of file not at end of a line; newline inserted
# /usr/bin/ld: warning: cannot find entry symbol _start; defaulting to 0000000000001000
# ...

# %%
# %%file /tmp/test.c
# #include <assert.h>
# #include <stdbool.h>
# int my_foo(int x);
# bool step_rel(int x, int y);
#
# int foo(int x){
#     int y = 2 * x;
#     assert( y == my_foo(x));
#     assert( step_rel(x,y));
#     return y;
#
# }
# Out:
# Overwriting /tmp/test.c

# %%
# !cbmc /tmp/test.c --function foo --smt2  --outfile testout --dump-smt-formula testdump.smt2
# Out:
# CBMC version 5.95.1 (cbmc-5.95.1) 64-bit x86_64 linux
# Parsing /tmp/test.c
# Converting
# Type-checking test
# Generating GOTO Program
# Adding CPROVER library (x86_64)
# Removal of function pointers and virtual functions
# Generic Property Instrumentation
# Running with 8 object bits, 56 offset bits (default)
# Starting Bounded Model Checking
# Outputting SMTLib formula to file: testout
# **** WARNING: no body for function my_foo
# Runtime Symex: 0.00066067s
# size of program expression: 31 steps
# simple slicing removed 5 assignments
# Generated 1 VCC(s), 1 remaining after simplification
# Runtime Postprocess Equation: 1.0518e-05s
# Passing problem to SMT2
# converting SSA
# Runtime Convert SSA: 0.000122752s
# Running SMT2
# Runtime Solver: 2.3347e-05s
# Runtime decision procedure: 0.000175481s
